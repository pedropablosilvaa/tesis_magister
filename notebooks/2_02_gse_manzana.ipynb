# %%
import pandas as pd

# %%
# %%time
manzana_gse = pd.read_csv("../data/GIS/inicial/gse/pedro_pruebas_geo_data_cityblocks_unique_gse.csv")
manzana_gse.head()
# Out:
# CPU times: user 2.62 s, sys: 100 ms, total: 2.72 s
# Wall time: 2.72 s
#   MANZ_EN  code_region  code_province  code_commune  code_district  \
# 0  URBANO            4             41          4101         410114
# 1  URBANO            4             41          4101         410114
# 2  URBANO            4             41          4101         410114
# 3  URBANO            4             41          4101         410114
# 4  URBANO            4             41          4101         410114
#
#     code_zone  code_cityblock  code_cityblock_unico  total_people GSE_N  \
# 0  4101141001   4101141001015      4101141001015001          46.0     E
# 1  4101141001   4101141001003      4101141001003001         131.0     D
# 2  4101141001   4101141001019      4101141001019001          73.0     D
# 3  4101141001   4101141001033      4101141001033001          45.0     D
# 4  4101141001   4101141001009      4101141001009001          55.0     E
#
#                                             geometry
# ...

# %%
manzana_gse_x = manzana_gse[manzana_gse['code_region'] == 10]
manzana_gse_x.head()
# Out:
#       MANZ_EN  code_region  code_province  code_commune  code_district  \
# 41389  URBANO           10            103         10301        1030114
# 41390  URBANO           10            103         10301        1030114
# 41391  URBANO           10            103         10301        1030114
# 41392  URBANO           10            103         10301        1030114
# 41393  URBANO           10            103         10301        1030114
#
#          code_zone  code_cityblock  code_cityblock_unico  total_people GSE_N  \
# 41389  10301141001  10301141001003     10301141001003001          71.0     D
# 41390  10301141001  10301141001012     10301141001012001          34.0    C2
# 41391  10301141001  10301141001013     10301141001013001          18.0   C1b
# 41392  10301141001  10301141001018     10301141001018001          70.0    C3
# 41393  10301141001  10301141001002     10301141001002001         128.0    C3
#
#                                                 geometry
# ...
